# %%
import pandas as pd

# %%
#df = pd.read_csv("artifacts/gnnexplainer_grid/20260504_191312/MoleculeQDetector/positive_explainability_results.csv")
df = pd.read_csv(
    "/home/dominik/MyStuff/bxaic2/artifacts/gnnexplainer_grid/20260505_150202/MoleculeQDetector/positive_explainability_results.csv")

# %%
tested = 0

for col in df.columns[1:]:
    if not "auroc" in col:
        continue

    tested += 1

    mean = df[col].mean()

    if mean > 0.5:
        print("Found column with mean > 0.5:", col)

print("Tested", tested, "columns.")
# Out:
# Tested 11026 columns.
